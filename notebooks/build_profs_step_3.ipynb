# %%
import pandas as pd
import numpy as np
from functools import partial

profs_df = pd.read_csv("../files/profiles/officers_index_step_2.csv")
profs_df.reset_index()

def get_uid_at(slot: int, uids):
  try:
    return uids.sort_values().iat[slot]
  except:
    return np.nan

"""
  Identify officers with the similar identifying info but a different last name, and assign them the same UID.
  This is meant to account for last-name changes due to marriage etc.
"""
grouped = profs_df.groupby(["off_first_name", "off_middle_initial", "off_sex", "off_year_of_birth", "off_race", "off_appointed", "off_star_0"]).agg(
  unique_ids = ("off_uniq_id", lambda uids: ','.join(uids.unique().astype(str))),
  unique_id_0 = ("off_uniq_id", partial(get_uid_at, 0)),
  unique_id_1 = ("off_uniq_id", partial(get_uid_at, 1)),
  size = ("off_uniq_id", "size")
)
grouped = grouped.reset_index().sort_values("size", ascending=False)
multi_matches = grouped[grouped["size"] > 1]
multi_matches.to_csv("../files/profiles/multi_last_name.csv", index=False)
for row in multi_matches.itertuples():
  print(row.unique_id_0, profs_df.loc[row.unique_id_0, "off_uniq_id"])
  print(int(row.unique_id_1), profs_df.loc[row.unique_id_1, "off_uniq_id"])
  profs_df.loc[int(row.unique_id_1), "off_uniq_id"] = int(row.unique_id_0)
  print("converted from, to", int(row.unique_id_1), profs_df.loc[row.unique_id_1, "off_uniq_id"])
profs_df.to_csv("../files/profiles/officers_index_step_3.csv", index=False)
# Out:
# 21816 21816
# 30592 30592
# converted from, to 30592 21816
# 7776 7776
# 21154 21154
# converted from, to 21154 7776
# 13194 13194
# 18770 18770
# converted from, to 18770 13194
# 17219 17219
# 17220 17220
# converted from, to 17220 17219
# 5329 5329
# 8986 8986
# converted from, to 8986 5329
# 3000 3000
# 3147 3147
# converted from, to 3147 3000
# 35630 35630
# 35631 35631
# converted from, to 35631 35630
# 14342 14342
# 24817 24817
# converted from, to 24817 14342
# 5832 5832
# 9324 9324
# converted from, to 9324 5832
# 6645 6645
# 19781 19781
# converted from, to 19781 6645
# 896 896
# 11459 11459
# converted from, to 11459 896
# 12791 12791
# 22790 22790
# converted from, to 22790 12791
# 3048 3048
# 28137 28137
# converted from, to 28137 3048
# 1057 1057
# 28435 28435
# converted from, to 28435 1057
# 24548 24548
# 24549 24549
# converted from, to 24549 24548
# 6283 6283
# 21293 21293
# converted from, to 21293 6283
# 18115 18115
# 31362 31362
# converted from, to 31362 18115
# 15350 15350
# 32170 32170
# converted from, to 32170 15350
# 19095 19095
# 31157 31157
# converted from, to 31157 19095
# 5278 5278
# 15942 15942
# converted from, to 15942 5278
# 7158 7158
# 21791 21791
# converted from, to 21791 7158
# 28422 28422
# 33395 33395
# converted from, to 33395 28422
# 12256 12256
# 32202 32202
# converted from, to 32202 12256
# 27245 27245
# 31969 31969
# converted from, to 31969 27245
# 16040 16040
# 16041 16041
# converted from, to 16041 16040
# 5032 5032
# 31583 31583
# converted from, to 31583 5032
# 5096 5096
# 19574 19574
# converted from, to 19574 5096
# 21151 21151
# 25053 25053
# converted from, to 25053 21151
# 31638 31638
# 31698 31698
# converted from, to 31698 31638
# 14270 14270
# 19367 19367
# converted from, to 19367 14270
# 25210 25210
# 32169 32169
# converted from, to 32169 25210
# 16539 16539
# 34492 34492
# converted from, to 34492 16539
# 34975 34975
# 35082 35082
# converted from, to 35082 34975
# 9548 9548
# 9560 9560
# converted from, to 9560 9548
# 19621 19621
# 28197 28197
# converted from, to 28197 19621
# 8740 8740
# 15051 15051
# converted from, to 15051 8740
# 9502 9502
# 33205 33205
# converted from, to 33205 9502
# 9144 9144
# 30169 30169
# converted from, to 30169 9144
# 9155 9155
# 22329 22329
# converted from, to 22329 9155
# 7097 7097
# 26984 26984
# converted from, to 26984 7097
# 6094 6094
# 17072 17072
# converted from, to 17072 6094
# 2783 2783
# 3490 3490
# converted from, to 3490 2783
# 22563 22563
# 33744 33744
# converted from, to 33744 22563
# 19531 19531
# 26096 26096
# converted from, to 26096 19531
# 30121 30121
# 30134 30134
# converted from, to 30134 30121
# 27204 27204
# 31284 31284
# converted from, to 31284 27204
# 15155 15155
# 15188 15188
# converted from, to 15188 15155
# 6969 6969
# 8547 8547
# converted from, to 8547 6969
# 7674 7674
# 19161 19161
# converted from, to 19161 7674
# 13730 13730
# 27299 27299
# converted from, to 27299 13730
# 5866 5866
# 5868 5868
# converted from, to 5868 5866
# 34298 34298
# 34313 34313
# converted from, to 34313 34298
# 22845 22845
# 26525 26525
# converted from, to 26525 22845
# 13834 13834
# 32504 32504
# converted from, to 32504 13834
# 3618 3618
# 3623 3623
# converted from, to 3623 3618
# 3080 3080
# 28489 28489
# converted from, to 28489 3080
# 8021 8021
# 26978 26978
# converted from, to 26978 8021
# 30911 30911
# 31560 31560
# converted from, to 31560 30911
# 6023 6023
# 19581 19581
# converted from, to 19581 6023
# 15457 15457
# 34388 34388
# converted from, to 34388 15457
# 2517 2517
# 3145 3145
# converted from, to 3145 2517
# 10083 10083
# 12672 12672
# converted from, to 12672 10083
# 22798 22798
# 22800 22800
# converted from, to 22800 22798
# 22540 22540
# 22541 22541
# converted from, to 22541 22540
# 31417 31417
# 33863 33863
# converted from, to 33863 31417
# 10676 10676
# 10680 10680
# converted from, to 10680 10676
# 29033 29033
# 35876 35876
# converted from, to 35876 29033
# 6446 6446
# 21276 21276
# converted from, to 21276 6446
# 4229 4229
# 34456 34456
# converted from, to 34456 4229
# 3318 3318
# 6324 6324
# converted from, to 6324 3318
